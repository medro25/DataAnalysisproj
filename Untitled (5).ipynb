# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\erraf\appdata\roaming\python\python310\site-packages (1.5.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\erraf\appdata\roaming\python\python310\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\erraf\appdata\roaming\python\python310\site-packages (from pandas) (1.22.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\erraf\appdata\roaming\python\python310\site-packages (from pandas) (2022.6)
# Requirement already satisfied: six>=1.5 in c:\users\erraf\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# read data from a CSV file
df = pd.read_csv('Production_Crops_Livestock_E_All_Data.csv', encoding='ISO-8859-1')
df
# Out:
#        Area Code Area Code (M49)                                     Area  \
# 0              2            '004                              Afghanistan
# 1              2            '004                              Afghanistan
# 2              2            '004                              Afghanistan
# 3              2            '004                              Afghanistan
# 4              2            '004                              Afghanistan
# ...          ...             ...                                      ...
# 79292       5817            '902  Net Food Importing Developing Countries
# 79293       5817            '902  Net Food Importing Developing Countries
# 79294       5817            '902  Net Food Importing Developing Countries
# 79295       5817            '902  Net Food Importing Developing Countries
# 79296       5817            '902  Net Food Importing Developing Countries
#
#        Item Code Item Code (CPC)  \
# 0            221          '01371
# 1            221          '01371
# 2            221          '01371
# 3            711          '01654
# 4            711          '01654
# ...          ...             ...
# 79292       1729          'F1729
# 79293       1729          'F1729
# 79294       1735          'F1735
# 79295       1735          'F1735
# 79296       1735          'F1735
#
#                                                     Item  Element Code  \
# 0                                      Almonds, in shell          5312
# 1                                      Almonds, in shell          5419
# 2                                      Almonds, in shell          5510
# 3      Anise, badian, coriander, cumin, caraway, fenn...          5312
# 4      Anise, badian, coriander, cumin, caraway, fenn...          5419
# ...                                                  ...           ...
# 79292                                    Treenuts, Total          5419
# 79293                                    Treenuts, Total          5510
# 79294                                 Vegetables Primary          5312
# 79295                                 Vegetables Primary          5419
# 79296                                 Vegetables Primary          5510
#
#               Element    Unit       Y1961  ...        Y2017  Y2017F  \
# 0      Area harvested      ha         NaN  ...     19793.00       A
# 1               Yield   hg/ha         NaN  ...     13788.00       A
# 2          Production  tonnes         NaN  ...     27291.00       A
# 3      Area harvested      ha         NaN  ...     26160.00       I
# 4               Yield   hg/ha         NaN  ...      6970.00       E
# ...               ...     ...         ...  ...          ...     ...
# 79292           Yield   hg/ha      6118.0  ...      5927.00       E
# 79293      Production  tonnes    255724.0  ...   2299639.12       E
# 79294  Area harvested      ha   1877800.0  ...   7217374.00       E
# 79295           Yield   hg/ha     66297.0  ...    116623.00       E
# 79296      Production  tonnes  12449173.0  ...  84171473.81       E
#
#              Y2018  Y2018F        Y2019  Y2019F        Y2020  Y2020F  \
# 0         20053.00       A     29203.00       A     22134.00       A
# 1         17161.00       A     13083.00       A     17759.00       A
# 2         34413.00       A     38205.00       A     39307.00       A
# 3         25220.00       E     27387.00       I     26255.00       E
# 4          7866.00       E      6902.00       E      7409.00       E
# ...            ...     ...          ...     ...          ...     ...
# 79292      5338.00       E      5346.00       E      5426.00       E
# 79293   2495666.54       E   2314274.21       E   2479586.92       E
# 79294   7429029.00       E   7543355.00       E   7710160.00       E
# 79295    116194.00       E    117830.00       E    117831.00       E
# 79296  86320503.75       E  88883639.40       E  90849506.59       E
#
#              Y2021  Y2021F
# 0         21685.00       I
# 1         18748.00       E
# 2         40655.23       I
# 3         26287.00       E
# 4          7379.00       E
# ...            ...     ...
# 79292      5515.00       E
# 79293   2498539.75       E
# 79294   7978161.00       E
# 79295    117360.00       E
# 79296  93631442.78       E
#
# [79297 rows x 131 columns]

# %%
# Cleaning the data 
# extract rows that include data for maize (corn), rice, wheat, barley, and sorghum
df = pd.read_csv('Production_Crops_Livestock_E_All_Data.csv', encoding='ISO-8859-1')
# Select the columns you want to extract based on the year
columns_to_extract = ['Item','Element','Area', 'Y2000', 'Y2005', 'Y2010', 'Y2015', 'Y2020']

# Create a new dataframe with the selected years
df_new = df[columns_to_extract]
# Create a new dataframe with the selected years and only production values shown
df_chart = pd.DataFrame(columns=['Item','Element','Area', 'Y2000', 'Y2005', 'Y2010', 'Y2015', 'Y2020'])
for index, row in df.iterrows():


 crop = row['Item']
 if crop in ['Maize (corn)', 'Rice', 'Wheat', 'Barley', 'Sorghum']and row['Element'] == 'Production':
        #print(index,row['Item'],row['Area'],row['Element'],row['Y2005'])
         df_chart.loc[index] = [row['Item'], row['Element'], row['Area'], row['Y2000'], row['Y2005'], row['Y2010'], row['Y2015'], row['Y2020']]
        
      
#print(df_chart)
print(df_chart.columns)
# Out:
# Index(['Item', 'Element', 'Area', 'Y2000', 'Y2005', 'Y2010', 'Y2015', 'Y2020'], dtype='object')

# %%
# Extract the worlwide production values
# Extract the data for Maize, Rice, Wheat, Barley, and Sorghum
df_crops = df[(df['Item'].isin(['Maize (corn)', 'Rice', 'Wheat', 'Barley', 'Sorghum'])) & (df['Element'] == 'Production')]

# Group the dataframe by crop and year, and then sum the values for each group
df_sum = df_crops.groupby(['Item'])[['Y2000', 'Y2005', 'Y2010', 'Y2015', 'Y2020']].sum()

# Print the result
print(df_sum)
print(df_sum.columns)
# Out:
#                      Y2000         Y2005         Y2010         Y2015  \
# Item
# Barley        5.917651e+08  6.147988e+08  5.621447e+08  6.736593e+08
# Maize (corn)  2.632245e+09  3.192467e+09  3.842675e+09  4.769702e+09
# Rice          2.984591e+09  3.168811e+09  3.501518e+09  3.699342e+09
# Sorghum       2.684730e+08  2.995830e+08  3.133303e+08  3.395023e+08
# Wheat         2.724245e+09  2.907134e+09  2.997627e+09  3.469615e+09
#
#                      Y2020
# Item
# Barley        7.100669e+08
# Maize (corn)  5.263329e+09
# Rice          3.903665e+09
# Sorghum       3.192200e+08
# Wheat         3.533445e+09
# Index(['Y2000', 'Y2005', 'Y2010', 'Y2015', 'Y2020'], dtype='object')

# %%
import matplotlib.pyplot as plt

# Transpose the dataframe so that years become rows and crops become columns
df_transposed = df_sum.T

# Plot a line chart for each crop
for crop in df_transposed.columns:
    plt.plot(df_transposed.index, df_transposed[crop], label=crop)

# Set the title, x-axis label, and y-axis label
plt.title('Worldwide Production of Maize, Rice, Wheat, Barley, and Sorghum')
plt.xlabel('Year')
plt.ylabel('Production (tonnes)')

# Add a legend and show the chart
plt.legend()
plt.show()

# %%
df_chart
print(df_chart.columns)
# Out:
# Index(['Item', 'Element', 'Area', 'Y2000', 'Y2005', 'Y2010', 'Y2015', 'Y2020'], dtype='object')

# %%
# create a new dataframe with only the desired columns
df_largest = df_chart.loc[:, ['Item', 'Area', 'Y2020']]

# print the new dataframe
print(df_largest)
print(df_largest.columns)
# Out:
#                Item                                     Area         Y2020
# 15           Barley                              Afghanistan  1.277570e+05
# 63     Maize (corn)                              Afghanistan  2.717760e+05
# 161            Rice                              Afghanistan  4.395490e+05
# 192           Wheat                              Afghanistan  5.185000e+06
# 257          Barley                                  Albania  1.264500e+04
# ...             ...                                      ...           ...
# 78647        Barley  Net Food Importing Developing Countries  4.137098e+06
# 78888  Maize (corn)  Net Food Importing Developing Countries  8.462362e+07
# 79131          Rice  Net Food Importing Developing Countries  1.518030e+08
# 79160       Sorghum  Net Food Importing Developing Countries  2.043418e+07
# 79228         Wheat  Net Food Importing Developing Countries  5.424741e+07
#
# [877 rows x 3 columns]
# Index(['Item', 'Area', 'Y2020'], dtype='object')

# %%
#Remove the column that are unwanted
dg = pd.read_csv('Production_Crops_Livestock_E_All_Data.csv', encoding='ISO-8859-1', skiprows=0, nrows=61273)
print(dg)
# Out:
#        Area Code Area Code (M49)         Area  Item Code Item Code (CPC)  \
# 0              2            '004  Afghanistan        221          '01371
# 1              2            '004  Afghanistan        221          '01371
# 2              2            '004  Afghanistan        221          '01371
# 3              2            '004  Afghanistan        711          '01654
# 4              2            '004  Afghanistan        711          '01654
# ...          ...             ...          ...        ...             ...
# 61268        181            '716     Zimbabwe       1729          'F1729
# 61269        181            '716     Zimbabwe       1729          'F1729
# 61270        181            '716     Zimbabwe       1729          'F1729
# 61271        181            '716     Zimbabwe       1735          'F1735
# 61272        181            '716     Zimbabwe       1735          'F1735
#
#                                                     Item  Element Code  \
# 0                                      Almonds, in shell          5312
# 1                                      Almonds, in shell          5419
# 2                                      Almonds, in shell          5510
# 3      Anise, badian, coriander, cumin, caraway, fenn...          5312
# 4      Anise, badian, coriander, cumin, caraway, fenn...          5419
# ...                                                  ...           ...
# 61268                                    Treenuts, Total          5312
# 61269                                    Treenuts, Total          5419
# 61270                                    Treenuts, Total          5510
# 61271                                 Vegetables Primary          5312
# 61272                                 Vegetables Primary          5419
#
#               Element    Unit    Y1961  ...     Y2017  Y2017F     Y2018  \
# 0      Area harvested      ha      NaN  ...  19793.00       A  20053.00
# 1               Yield   hg/ha      NaN  ...  13788.00       A  17161.00
# 2          Production  tonnes      NaN  ...  27291.00       A  34413.00
# 3      Area harvested      ha      NaN  ...  26160.00       I  25220.00
# 4               Yield   hg/ha      NaN  ...   6970.00       E   7866.00
# ...               ...     ...      ...  ...       ...     ...       ...
# 61268  Area harvested      ha      NaN  ...   3476.00       E   3414.00
# 61269           Yield   hg/ha      NaN  ...  18670.00       E  19307.00
# 61270      Production  tonnes      NaN  ...   6489.28       E   6592.03
# 61271  Area harvested      ha  12296.0  ...  34648.00       E  35756.00
# 61272           Yield   hg/ha  65324.0  ...  67140.00       E  66013.00
#
#        Y2018F     Y2019  Y2019F     Y2020  Y2020F     Y2021  Y2021F
# 0           A  29203.00       A  22134.00       A  21685.00       I
# 1           A  13083.00       A  17759.00       A  18748.00       E
# 2           A  38205.00       A  39307.00       A  40655.23       I
# 3           E  27387.00       I  26255.00       E  26287.00       E
# 4           E   6902.00       E   7409.00       E   7379.00       E
# ...       ...       ...     ...       ...     ...       ...     ...
# 61268       E   3327.00       E   3384.00       E   3261.00       E
# 61269       E  20183.00       E  20856.00       E  21544.00       E
# 61270       E   6715.72       E   7057.98       E   7025.62       E
# 61271       E  35020.00       E  35580.00       E  35148.00       E
# 61272       E  66678.00       E  65932.00       E  66770.00       E
#
# [61273 rows x 131 columns]

# %%
dg = pd.read_csv('Production_Crops_Livestock_E_All_Data.csv', encoding='ISO-8859-1', skiprows=0, nrows=61273)
#print(dg)


dg_crops = dg[(dg['Item'].isin(['Maize (corn)', 'Rice', 'Wheat', 'Barley', 'Sorghum'])) & (dg['Element'] == 'Production')]
#print(dg_crops)
print("here",dg_crops.columns)
# Group the dataframe by crop and year, and then sum the values for each group

dg_sumlargest = dg_crops.groupby(['Item', 'Area'])[['Y2020']].sum().reset_index()
#print(dg_sumlargest )
#print("here",dg_sumlargest.columns)

# Print the result
# Set pandas display options to show all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
#dg_sumlargest

dg_largest = dg_sumlargest.groupby('Item').apply(lambda x: x.nlargest(4, 'Y2020')).reset_index(level=0, drop=True)
print(dg_largest)
(dg_largest.columns)
# Out:
# here Index(['Area Code', 'Area Code (M49)', 'Area', 'Item Code', 'Item Code (CPC)',
#        'Item', 'Element Code', 'Element', 'Unit', 'Y1961',
#        ...
#        'Y2017', 'Y2017F', 'Y2018', 'Y2018F', 'Y2019', 'Y2019F', 'Y2020',
#        'Y2020F', 'Y2021', 'Y2021F'],
#       dtype='object', length=131)
#              Item                      Area         Y2020
# 84         Barley        Russian Federation  2.093899e+07
# 92         Barley                     Spain  1.146535e+07
# 39         Barley                   Germany  1.076920e+07
# 17         Barley                    Canada  1.074060e+07
# 288  Maize (corn)  United States of America  3.584473e+08
# 148  Maize (corn)                     China  2.608765e+08
# 150  Maize (corn)           China, mainland  2.606700e+08
# 137  Maize (corn)                    Brazil  1.039636e+08
# 322          Rice                     China  2.136107e+08
# 325          Rice           China, mainland  2.118600e+08
# 361          Rice                     India  1.865000e+08
# 306          Rice                Bangladesh  5.490589e+07
# 575       Sorghum  United States of America  9.473620e+06
# 531       Sorghum                   Nigeria  6.590000e+06
# 486       Sorghum                  Ethiopia  5.058043e+06
# 500       Sorghum                     India  4.772100e+06
# 608         Wheat                     China  1.342560e+08
# 610         Wheat           China, mainland  1.342500e+08
# 634         Wheat                     India  1.078605e+08
# 683         Wheat        Russian Federation  8.589633e+07
# Index(['Item', 'Area', 'Y2020'], dtype='object')

# %%
import matplotlib.pyplot as plt

# Define the list of countries and their colors
countries = {
    "Bangladesh": "#8c564b",
    "Brazil": "#1f77b4",
    "Canada": "#ff7f0e",
    "China": "#2ca02c",
    "China, mainland": "#9467bd",
    "Ethiopia": "#e377c2",
    "Germany": "#7f7f7f",
    "India": "#d62728",
    "Nigeria": "#bcbd22",
    "Russian Federation": "#17becf",
    "Spain": "#e377c2",
    "United States of America": "#8c564b"
}

# Pivot the DataFrame to create a wide format suitable for a stacked bar chart

df_pivot = dg_largest.pivot(index='Item', columns='Area', values='Y2020')
#print(df_pivot)
# Create a stacked bar chart
df_pivot.plot(kind='bar', stacked=True, color=[countries[c] for c in df_pivot.columns])

# Customize the chart with labels and titles
plt.title('Production of Top 4 Countries per Crop in 2020')
plt.xlabel('Crop')
plt.ylabel('Production (tonnes)')


# Display the chart
plt.show()

# %%
# Group the dataframe by crop and year, and then sum the values for each group

dg_sumlargest = dg_crops.groupby(['Item', 'Area'])[['Y2015']].sum().reset_index()
#print(dg_sumlargest )
#print("here",dg_sumlargest.columns)

# Print the result
# Set pandas display options to show all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
#dg_sumlargest

dg_largest = dg_sumlargest.groupby('Item').apply(lambda x: x.nlargest(4, 'Y2015')).reset_index(level=0, drop=True)
print(dg_largest)
print(dg_largest.columns)
# Out:
#              Item                      Area         Y2015
# 84         Barley        Russian Federation  1.754616e+07
# 37         Barley                    France  1.309823e+07
# 39         Barley                   Germany  1.162990e+07
# 5          Barley                 Australia  8.646321e+06
# 288  Maize (corn)  United States of America  3.454863e+08
# 148  Maize (corn)                     China  2.651573e+08
# 150  Maize (corn)           China, mainland  2.649920e+08
# 137  Maize (corn)                    Brazil  8.528307e+07
# 322          Rice                     China  2.137237e+08
# 325          Rice           China, mainland  2.121420e+08
# 361          Rice                     India  1.565400e+08
# 362          Rice                 Indonesia  6.103100e+07
# 575       Sorghum  United States of America  1.515817e+07
# 531       Sorghum                   Nigeria  7.005025e+06
# 500       Sorghum                     India  5.450000e+06
# 521       Sorghum                    Mexico  5.195389e+06
# 608         Wheat                     China  1.326463e+08
# 610         Wheat           China, mainland  1.326390e+08
# 634         Wheat                     India  8.653000e+07
# 683         Wheat        Russian Federation  6.178580e+07
# Index(['Item', 'Area', 'Y2015'], dtype='object')

# %%
import matplotlib.pyplot as plt

# Define the list of countries and their colors
countries = {
    "Australia": "#8c564b",
    "Brazil": "#1f77b4",
    "China": "#2ca02c",
    "China, mainland": "#9467bd",
    "France": "#7f7f7f",
    "Germany": "#d62728",
    "India": "#e377c2",
    "Indonesia": "#bcbd22",
    "Mexico": "#17becf",
    "Nigeria": "#ff7f0e",
    "Russian Federation": "#4e79a7",
    "United States of America": "#f28e2c"
}

# Pivot the DataFrame to create a wide format suitable for a stacked bar chart

df_pivot = dg_largest.pivot(index='Item', columns='Area', values='Y2015')

# Create a stacked bar chart
df_pivot.plot(kind='bar', stacked=True, color=[countries[c] for c in df_pivot.columns])

# Customize the chart with labels and titles
plt.title('Production of Top 4 Countries per Crop in 2015')
plt.xlabel('Crop')
plt.ylabel('Production (tonnes)')

# Move the legend to the right side
ax = plt.gca()
ax.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))

# Display the chart
plt.show()

# %%
dg_crops = dg[(dg['Item'].isin(['Maize (corn)', 'Rice', 'Wheat', 'Barley', 'Sorghum'])) & (dg['Element'] == 'Production')]
#print(dg_crops)
print("here",dg_crops.columns)
# Group the dataframe by crop and year, and then sum the values for each group

dg_sumlargest = dg_crops.groupby(['Item', 'Area'])[['Y2010']].sum().reset_index()
#print(dg_sumlargest )
print("here",dg_sumlargest.columns)

# Print the result
# Set pandas display options to show all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
#dg_sumlargest

dg_largest = dg_sumlargest.groupby('Item').apply(lambda x: x.nlargest(4, 'Y2010')).reset_index(level=0, drop=True)
#print(dg_largest)
#(dg_largest.columns)
print(dg_largest)
# Out:
# here Index(['Area Code', 'Area Code (M49)', 'Area', 'Item Code', 'Item Code (CPC)',
#        'Item', 'Element Code', 'Element', 'Unit', 'Y1961',
#        ...
#        'Y2017', 'Y2017F', 'Y2018', 'Y2018F', 'Y2019', 'Y2019F', 'Y2020',
#        'Y2020F', 'Y2021', 'Y2021F'],
#       dtype='object', length=131)
# here Index(['Item', 'Area', 'Y2010'], dtype='object')
#              Item                      Area         Y2010
# 39         Barley                   Germany  1.032692e+07
# 37         Barley                    France  1.010160e+07
# 104        Barley                   Ukraine  8.484900e+06
# 84         Barley        Russian Federation  8.350022e+06
# 288  Maize (corn)  United States of America  3.156179e+08
# 148  Maize (corn)                     China  1.775408e+08
# 150  Maize (corn)           China, mainland  1.774250e+08
# 137  Maize (corn)                    Brazil  5.536427e+07
# 322          Rice                     China  1.972120e+08
# 325          Rice           China, mainland  1.957610e+08
# 361          Rice                     India  1.439630e+08
# 362          Rice                 Indonesia  5.928300e+07
# 575       Sorghum  United States of America  8.775190e+06
# 531       Sorghum                   Nigeria  7.140970e+06
# 521       Sorghum                    Mexico  6.940225e+06
# 500       Sorghum                     India  6.698200e+06
# 608         Wheat                     China  1.151862e+08
# 610         Wheat           China, mainland  1.151810e+08
# 634         Wheat                     India  8.080360e+07
# 710         Wheat  United States of America  6.006241e+07

# %%
# Define the list of countries and their colors
countries = {
    "Bangladesh": "#FF5733",
    "Brazil": "#1F618D",
    "Canada": "#F4D03F",
    "China": "#196F3D",
    "China, mainland": "#CD5C5C",
    "Ethiopia": "#A569BD",
    "France": "#F0B27A",
    "Germany": "#6C3483",
    "India": "#DC7633",
    "Indonesia": "#7D3C98",
    "Mexico": "#C39BD3",
    "Nigeria": "#27AE60",
    "Russian Federation": "#3498DB",
    "Ukraine": "#E74C3C",
    "United States of America": "#2ECC71"
}

# Pivot the DataFrame to create a wide format suitable for a stacked bar chart
df_pivot = dg_largest.pivot(index='Item', columns='Area', values='Y2010')

# Create a stacked bar chart
df_pivot.plot(kind='bar', stacked=True, color=[countries[c] for c in df_pivot.columns])

# Customize the chart with labels and titles
plt.title('Production of Top 4 Countries per Crop in 2010')
plt.xlabel('Crop')
plt.ylabel('Production (tonnes)')
# Move the legend to the right side
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# Display the chart
plt.show()

# %%
dg_crops = dg[(dg['Item'].isin(['Maize (corn)', 'Rice', 'Wheat', 'Barley', 'Sorghum'])) & (dg['Element'] == 'Production')]
#print(dg_crops)
print("here",dg_crops.columns)
# Group the dataframe by crop and year, and then sum the values for each group

dg_sumlargest = dg_crops.groupby(['Item', 'Area'])[['Y2005']].sum().reset_index()
#print(dg_sumlargest )
print("here",dg_sumlargest.columns)

# Print the result
# Set pandas display options to show all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
#dg_sumlargest

dg_largest = dg_sumlargest.groupby('Item').apply(lambda x: x.nlargest(4, 'Y2005')).reset_index(level=0, drop=True)
#print(dg_largest)
#(dg_largest.columns)
print(dg_largest)
# Out:
# here Index(['Area Code', 'Area Code (M49)', 'Area', 'Item Code', 'Item Code (CPC)',
#        'Item', 'Element Code', 'Element', 'Unit', 'Y1961',
#        ...
#        'Y2017', 'Y2017F', 'Y2018', 'Y2018F', 'Y2019', 'Y2019F', 'Y2020',
#        'Y2020F', 'Y2021', 'Y2021F'],
#       dtype='object', length=131)
# here Index(['Item', 'Area', 'Y2005'], dtype='object')
#              Item                      Area         Y2005
# 84         Barley        Russian Federation  1.568378e+07
# 17         Barley                    Canada  1.167760e+07
# 39         Barley                   Germany  1.161380e+07
# 37         Barley                    France  1.031359e+07
# 288  Maize (corn)  United States of America  2.822626e+08
# 148  Maize (corn)                     China  1.394985e+08
# 150  Maize (corn)           China, mainland  1.393650e+08
# 137  Maize (corn)                    Brazil  3.511331e+07
# 322          Rice                     China  1.820551e+08
# 325          Rice           China, mainland  1.805880e+08
# 361          Rice                     India  1.376901e+08
# 362          Rice                 Indonesia  5.415110e+07
# 575       Sorghum  United States of America  9.976030e+06
# 531       Sorghum                   Nigeria  9.178000e+06
# 500       Sorghum                     India  7.244300e+06
# 521       Sorghum                    Mexico  5.524384e+06
# 608         Wheat                     China  9.744520e+07
# 610         Wheat           China, mainland  9.744500e+07
# 634         Wheat                     India  6.863690e+07
# 710         Wheat  United States of America  5.724199e+07

# %%
dg_sumlargest = dg_crops.groupby(['Item', 'Area'])[['Y2005']].sum().reset_index()
#print(dg_sumlargest )
print("here",dg_sumlargest.columns)

# Print the result
# Set pandas display options to show all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
#dg_sumlargest

dg_largest = dg_sumlargest.groupby('Item').apply(lambda x: x.nlargest(4, 'Y2005')).reset_index(level=0, drop=True)
#print(dg_largest)
#(dg_largest.columns)
print(dg_largest)
# Out:
# here Index(['Item', 'Area', 'Y2005'], dtype='object')
#              Item                      Area         Y2005
# 84         Barley        Russian Federation  1.568378e+07
# 17         Barley                    Canada  1.167760e+07
# 39         Barley                   Germany  1.161380e+07
# 37         Barley                    France  1.031359e+07
# 288  Maize (corn)  United States of America  2.822626e+08
# 148  Maize (corn)                     China  1.394985e+08
# 150  Maize (corn)           China, mainland  1.393650e+08
# 137  Maize (corn)                    Brazil  3.511331e+07
# 322          Rice                     China  1.820551e+08
# 325          Rice           China, mainland  1.805880e+08
# 361          Rice                     India  1.376901e+08
# 362          Rice                 Indonesia  5.415110e+07
# 575       Sorghum  United States of America  9.976030e+06
# 531       Sorghum                   Nigeria  9.178000e+06
# 500       Sorghum                     India  7.244300e+06
# 521       Sorghum                    Mexico  5.524384e+06
# 608         Wheat                     China  9.744520e+07
# 610         Wheat           China, mainland  9.744500e+07
# 634         Wheat                     India  6.863690e+07
# 710         Wheat  United States of America  5.724199e+07

# %%
# Define the list of countries and their colors
countries = {
    "Brazil": "#1F618D",
    "Canada": "#F4D03F",
    "China": "#196F3D",
    "China, mainland": "#CD5C5C",
    "France": "#F0B27A",
    "Germany": "#6C3483",
    "India": "#DC7633",
    "Indonesia": "#7D3C98",
    "Mexico": "#C39BD3",
    "Nigeria": "#27AE60",
    "Russian Federation": "#3498DB",
    "United States of America": "#2ECC71"
}

# Pivot the DataFrame to create a wide format suitable for a stacked bar chart
df_pivot = dg_largest.pivot(index='Item', columns='Area', values='Y2005')

# Create a stacked bar chart
df_pivot.plot(kind='bar', stacked=True, color=[countries[c] for c in df_pivot.columns])

# Customize the chart with labels and titles
plt.title('Production of Top 4 Countries per Crop in 2005')
plt.xlabel('Crop')
plt.ylabel('Production (tonnes)')
# Move the legend to the right side
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# Display the chart
plt.show()

# %%
# Group the dataframe by crop and year, and then sum the values for each group

dg_sumlargest = dg_crops.groupby(['Item', 'Area'])[['Y2021']].sum().reset_index()
#print(dg_sumlargest )
#print("here",dg_sumlargest.columns)

# Print the result
# Set pandas display options to show all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
#dg_sumlargest

dg_largest = dg_sumlargest.groupby('Item').apply(lambda x: x.nlargest(3, 'Y2021')).reset_index(level=0, drop=True)
print(dg_largest)
(dg_largest.columns)
# Out:
#              Item                      Area         Y2021
# 84         Barley        Russian Federation  1.799591e+07
# 5          Barley                 Australia  1.464858e+07
# 37         Barley                    France  1.132132e+07
# 288  Maize (corn)  United States of America  3.839430e+08
# 148  Maize (corn)                     China  2.727621e+08
# 150  Maize (corn)           China, mainland  2.725520e+08
# 322          Rice                     China  2.144039e+08
# 325          Rice           China, mainland  2.128430e+08
# 361          Rice                     India  1.954250e+08
# 575       Sorghum  United States of America  1.137490e+07
# 531       Sorghum                   Nigeria  6.725000e+06
# 500       Sorghum                     India  4.810000e+06
# 608         Wheat                     China  1.369520e+08
# 610         Wheat           China, mainland  1.369460e+08
# 634         Wheat                     India  1.095900e+08
# Index(['Item', 'Area', 'Y2021'], dtype='object')

# %%
# Group the dataframe by crop and year, and then sum the values for each groupamine

dg_sumlargest = dg_crops.groupby(['Item', 'Area'])[['Y2000']].sum().reset_index()
#print(dg_sumlargest )
print("here",dg_sumlargest.columns)

# Print the result
# Set pandas display options to show all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
#dg_sumlargest

dg_largest = dg_sumlargest.groupby('Item').apply(lambda x: x.nlargest(4, 'Y2000')).reset_index(level=0, drop=True)
#print(dg_largest)
#(dg_largest.columns)
print(dg_largest)
# Out:
# here Index(['Item', 'Area', 'Y2000'], dtype='object')
#              Item                      Area         Y2000
# 84         Barley        Russian Federation  1.403879e+07
# 17         Barley                    Canada  1.322860e+07
# 39         Barley                   Germany  1.210582e+07
# 92         Barley                     Spain  1.106301e+07
# 288  Maize (corn)  United States of America  2.518539e+08
# 148  Maize (corn)                     China  1.061783e+08
# 150  Maize (corn)           China, mainland  1.060000e+08
# 137  Maize (corn)                    Brazil  3.232100e+07
# 322          Rice                     China  1.898141e+08
# 325          Rice           China, mainland  1.879080e+08
# 361          Rice                     India  1.274649e+08
# 362          Rice                 Indonesia  5.189800e+07
# 575       Sorghum  United States of America  1.195191e+07
# 531       Sorghum                   Nigeria  7.711000e+06
# 500       Sorghum                     India  7.529400e+06
# 521       Sorghum                    Mexico  5.842308e+06
# 608         Wheat                     China  9.963613e+07
# 610         Wheat           China, mainland  9.963600e+07
# 634         Wheat                     India  7.636890e+07
# 710         Wheat  United States of America  6.063938e+07

# %%
# Group the dataframe by crop and year, and then sum the values for each groupamine

dg_sumlargest = dg_crops.groupby(['Item', 'Area'])[['Y2021']].sum().reset_index()

#print(dg_sumlargest )
print("here",dg_sumlargest.columns)

# Print the result
# Set pandas display options to show all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
#dg_sumlargest

dg_largest = dg_sumlargest.groupby('Item').apply(lambda x: x.nlargest(3, 'Y2021')).reset_index(level=0, drop=True)
#print(dg_largest)
#(dg_largest.columns)
#print(dg_largest)
# Create a list of all countries in the original dataset
all_countries = dg_sumlargest['Area'].unique()
# For each crop, get the countries that were not selected as the top 4
# For each crop, get the countries that were not selected as the top 4 and sum their values
dg_other = pd.DataFrame()
for crop in dg_largest['Item'].unique():
    top_countries = dg_largest[dg_largest['Item'] == crop]['Area'].unique()
    other_countries = list(set(all_countries) - set(top_countries))
    dg_other_crop = dg_sumlargest[(dg_sumlargest['Item'] == crop) & (dg_sumlargest['Area'].isin(other_countries))]
    other_sum = dg_other_crop['Y2021'].sum()
    dg_other_crop = dg_other_crop.iloc[:1, :]
    dg_other_crop['Area'] = 'Other'
    dg_other_crop['Y2021'] = other_sum
    dg_other = dg_other.append(dg_other_crop)
print (dg_other)
# Out:
# here Index(['Item', 'Area', 'Y2021'], dtype='object')
#              Item   Area         Y2021
# 0          Barley  Other  1.036581e+08
# 115  Maize (corn)  Other  5.537401e+08
# 298          Rice  Other  3.790259e+08
# 447       Sorghum  Other  4.145724e+07
# 584         Wheat  Other  5.243411e+08
# C:\Users\erraf\AppData\Local\Temp\ipykernel_22112\1824730429.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dg_other = dg_other.append(dg_other_crop)
# C:\Users\erraf\AppData\Local\Temp\ipykernel_22112\1824730429.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dg_other = dg_other.append(dg_other_crop)
# C:\Users\erraf\AppData\Local\Temp\ipykernel_22112\1824730429.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dg_other = dg_other.append(dg_other_crop)
# C:\Users\erraf\AppData\Local\Temp\ipykernel_22112\1824730429.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dg_other = dg_other.append(dg_other_crop)
# C:\Users\erraf\AppData\Local\Temp\ipykernel_22112\1824730429.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dg_other = dg_other.append(dg_other_crop)

# %%
# Define the list of countries and their colors
countries = {
    "Brazil": "#1F618D",
    "Canada": "#F4D03F",
    "China": "#196F3D",
    "China, mainland": "#CD5C5C",
    "France": "#F0B27A",
    "Germany": "#6C3483",
    "India": "#DC7633",
    "Indonesia": "#7D3C98",
    "Mexico": "#C39BD3",
    "Nigeria": "#27AE60",
    "Russian Federation": "#3498DB",
    "Spain": "#F7DC6F",
    "United States of America": "#2ECC71"
}

# Pivot the DataFrame to create a wide format suitable for a stacked bar chart
df_pivot = dg_largest.pivot(index='Item', columns='Area', values='Y2000')

# Create a stacked bar chart
df_pivot.plot(kind='bar', stacked=True, color=[countries[c] for c in df_pivot.columns])

# Customize the chart with labels and titles
plt.title('Production of Top 4 Countries per Crop in 2000')
plt.xlabel('Crop')
plt.ylabel('Production (tonnes)')
# Move the legend to the right side
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# Display the chart
plt.show()

# %%
import matplotlib.pyplot as plt

# Create a new dataframe with top 4 countries and "Other" for each crop
dg_plot = pd.concat([dg_largest, dg_other])

# Pivot the dataframe to have crops as rows and countries as columns
dg_plot = dg_plot.pivot(index='Item', columns='Area', values='Y2021').fillna(0)

# Convert the values to percentages
dg_plot = dg_plot.apply(lambda x: x/x.sum()*100, axis=1)

# Sort the rows by total value (sum of top 4 countries and "Other")
dg_plot = dg_plot.loc[dg_plot.sum(axis=1).sort_values(ascending=False).index]

# Plot the stacked bar chart
ax = dg_plot.plot(kind='bar', stacked=True, figsize=(10, 6),legend=None)
plt.xlabel('Crop')
plt.ylabel('Percentage')
plt.title('Top 4 countries and Other for each crop in 2021')
#plt.legend(title='Country', loc='upper left')

# Add country labels inside the bars
for i, (crop, row) in enumerate(dg_plot.iterrows()):
    offset = 0
    for country, value in row.iteritems():
        if value != 0:
            ax.text(i, offset + value/2, country, ha='center', va='center')
            offset += value

plt.show()
# Out:
# C:\Users\erraf\AppData\Local\Temp\ipykernel_22112\2856215864.py:25: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for country, value in row.iteritems():
